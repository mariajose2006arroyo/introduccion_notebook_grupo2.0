# %% [markdown]
# # Kaleth Martinez
#
# **Programa académico:** Ingeniería Ambiental
#
# La programación puede apoyar la Ingeniería Ambiental porque permite analizar grandes volúmenes de datos relacionados con el medio ambiente. Por ejemplo, se pueden estudiar niveles de contaminación del aire, calidad del agua o cambios climáticos. Además, permite automatizar análisis y generar reportes que ayudan a tomar decisiones para proteger los ecosistemas y mejorar la sostenibilidad.

# %%
print("La programación permite analizar datos ambientales y ayudar a proteger los ecosistemas.")
# Out:
# La programación permite analizar datos ambientales y ayudar a proteger los ecosistemas.
