# %% [markdown]
# # Maria Valentina Galeano Castillo

# %% [markdown]
# ¿Cómo puede la programación apoyar la Ingeniería Ambiental? # Valentina Castillo **Programa académico:** Ingeniería Ambiental La programación puede apoyar la Ingeniería Ambiental porque permite analizar grandes volúmenes de datos sobre calidad del agua, aire y suelo. También ayuda a automatizar reportes, simular escenarios ambientales y monitorear variables en tiempo real. Con herramientas tecnológicas se pueden tomar decisiones más rápidas y precisas para proteger los ecosistemas. Además, facilita la creación de soluciones sostenibles basadas en evidencia.

# %%
print("La programación permite monitorear la calidad del agua y detectar riesgos ambientales de forma más rápida y precisa.")
# Out:
# La programación permite monitorear la calidad del agua y detectar riesgos ambientales de forma más rápida y precisa.
