# %% [markdown]
# # Yuli Espinosa Acevedo
# ## Ingenieria Ambiental
# ### La progrmación puede apoyar la ingnieria ambiental permitiendo analizar datos ambientales de forma mas rapida y precisa. Por ejemplo se pueden estudair variables como la calidad del agua, la contaminación del aire, el cambio climatico mediante modelos y analisis de datos. Esto ayuda a tomar mejores decisisones para proteger los ecosistemas y gestionar los recursos naturales de manera sostenible.

# %%
print("La programación permite analizar la calidad del agaua y mejorar la gestión ambiental.")
# Out:
# La programación permite analizar la calidad del agaua y mejorar la gestión ambiental.
